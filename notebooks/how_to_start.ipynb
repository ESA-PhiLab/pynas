# %% [markdown]
# # PyNAS quick start
#
# This notebook verifies the installed `pynas` package by loading the bundled configuration, creating a tiny NAS population, building a segmentation model, and running CPU inference on synthetic data. Full training still requires the burned-area dataset described in the repository README.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Environment check

# %%
import torch
import pynas

print("PyNAS version:", pynas.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# PyNAS version: 0.1.0
# CUDA available: False
# CUDA version: None
# GPU count: 0
# GPU name: None

# %% [markdown]
# ## Load packaged configuration

# %%
from pynas.core.config import default_config_path, load_default_config

config = load_default_config()
print("Configuration loaded from:", default_config_path())
print("GA population_size:", config.getint("GA", "population_size"))
assert config.has_section("ConvAct")
assert config.has_section("GA")
# Out:
# Configuration loaded from: /Users/roberto.delprete/Downloads/pynas/src/pynas/core/config.ini
# GA population_size: 50

# %% [markdown]
# ## Build a lightweight NAS model

# %%
from pathlib import Path
from tempfile import TemporaryDirectory
from types import SimpleNamespace
import random

import pytorch_lightning as pl

from pynas.core.population import Population

seed = config.getint("Computation", "seed")
random.seed(seed)
torch.manual_seed(seed)
pl.seed_everything(seed=seed, workers=True)
torch.set_float32_matmul_precision("medium")

# Minimal datamodule-shaped object for model construction.
# Real training should use scripts.dataloader.SegmentationDataModule with the actual dataset.
dm = SimpleNamespace(input_shape=(3, 16, 16), num_classes=2)
workspace = TemporaryDirectory()
save_directory = Path(workspace.name)

pop = Population(
    n_individuals=2,
    max_layers=4,
    dm=dm,
    max_parameters=5_000_000,
    save_directory=save_directory,
)
individual = pop.create_random_individual()
model, is_valid = pop.build_model(individual.parsed_layers, task="segmentation")
params = pop.evaluate_parameters(model)

print("Architecture:", individual.architecture)
print("Model valid:", is_valid)
print("Parameter count:", params)
assert is_valid
assert params > 0
# Out:
# Seed set to 42
# Architecture: Lbo08k3s1p1arn1EPa2ELRr2arn1EPa2ELdo07arn1EPa2EE
# Model valid: True
# Parameter count: 74570

# %% [markdown]
# ## Run inference

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device).eval()
example_input = torch.randn(1, *dm.input_shape, device=device)

with torch.no_grad():
    output = model(example_input)

print("Output shape:", tuple(output.shape))
assert output.shape == (1, dm.num_classes, dm.input_shape[1], dm.input_shape[2])
# Out:
# Output shape: (1, 2, 16, 16)

# %% [markdown]
# ## Create and checkpoint an initial population

# %%
pop.initial_poll()
print(pop.df[["Generation", "Params"]])
assert len(pop.population) == pop.n_individuals
assert (save_directory / "src" / "population_0.pkl").exists()
assert (save_directory / "src" / "df_population_0.pkl").exists()
# Out:
# Generating Population: 100%|██████████| 2/2 [00:00<00:00,  2.35it/s]
#    Generation   Params
# 0           0    23261
# 1           0  1010396

# %% [markdown]
# ## Cleanup

# %%
workspace.cleanup()
print("PyNAS quick start completed successfully.")
# Out:
# PyNAS quick start completed successfully.
